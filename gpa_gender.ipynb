# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp

# %%
gpa_data=pd.read_csv("gpa_gender.csv")

x=gpa_data["Term"]
del gpa_data["Term"]


a=gpa_data["Female"]
b=gpa_data["Male"]
c=gpa_data["Entire Population"]


gpa_data
# Out:
#     Female  Male  Entire Population
# 0     3.05  2.94               3.00
# 1     3.06  2.96               3.01
# 2     3.07  2.97               3.02
# 3     3.05  2.96               3.01
# 4     3.06  2.96               3.01
# 5     3.07  2.97               3.02
# 6     3.05  2.96               3.01
# 7     3.05  2.97               3.01
# 8     3.07  2.98               3.03
# 9     3.05  2.98               3.01
# 10    3.06  2.99               3.02
# 11    3.07  3.00               3.04
# 12    3.05  2.99               3.02
# 13    3.06  2.99               3.03
# 14    3.07  3.00               3.03
# 15    3.03  2.99               3.01
# 16    3.04  2.99               3.02
# 17    3.06  3.00               3.03
# 18    3.03  2.98               3.01
# 19    3.04  2.99               3.01
# 20    3.05  3.00               3.03
# 21    3.04  2.98               3.01
# 22    3.04  2.98               3.01
# 23    3.06  3.00               3.03
# 24    3.04  2.99               3.02
# ...

# %%
#graph
mp.plot(a, linewidth=2, color="b")
mp.plot(b, linewidth=2, color="g")
mp.plot(c, linewidth=2, color="r")

mp.xticks(np.arange(48), x, rotation=90, fontsize=7)
mp.title("Mean Undergraduate Cumulative GPA by Gender")
mp.ylabel("Avg GPA")
mp.legend(loc="lower right")
mp.show()
